# %% [markdown]
# (1) Plot the Following signals from $n = -20$ to $n = 20$. Use the command
# stem to plot the signals. Clearly mark the time origin in each case.
# \begin{equation}\nonumber
# (i)~~(\frac{1}{3})^nu[n]-2^nu[−n-5]
# \end{equation}
# \begin{equation}\nonumber
#  (ii)~~~~~~~~~~~~3\sin(\pi\frac{n}{4}+\frac{\pi}{3})
# \end{equation}
# \begin{equation}\nonumber
#  (iii)~~~~~~~~~~~3\sin(3\pi\frac{n}{4}+\frac{\pi}{3})
# \end{equation}
# (what is the difference from above signal? Why?)
#
# \begin{equation}\nonumber
#  (iv)~~~~~~~~~~~~e^{-0.1n}\cos(\frac{n\pi}{8})
# \end{equation}
# \begin{equation}\nonumber
#  (v)~~~~~~~~~~~~~~~~~~~\frac{\sin(\frac{n\pi}{6})}{\frac{n\pi}{6}}
# \end{equation}

# %%
# %matplotlib inline

# %%
(i)

# %%
import numpy as np
import matplotlib.pyplot as plt
n=np.linspace(-20,20,40)
y=(np.power(1/3.0,n)*np.heaviside(n,1))-(pow(2,n)*np.heaviside(((-1*n)-5),1))
plt.stem(n,y,use_line_collection=(True))
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %%
(ii)

# %%
import numpy as np
n=np.linspace(-20,20,40)
y=3*np.sin((((np.pi*n)/4+(np.pi)/3)))
plt.stem(n,y,use_line_collection=(True))
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %%
(iii)

# %%
import numpy as np
n=np.linspace(-20,20,40)
y=3*np.sin((((3*(np.pi*n))/4)+((np.pi)/3)))
plt.stem(n,y,use_line_collection=(True))
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %%
(iv)

# %%
import numpy as np
n=np.linspace(-20,20,40)
y=np.exp(-1*0.1*n)*np.cos((n*np.pi)/8)
plt.stem(n,y,use_line_collection=(True))
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %%
(v)

# %%
import numpy as np
n=np.linspace(-20,20,40)
y=np.sin((n*np.pi)/6)/(n*np.pi/6)
plt.stem(n,y,use_line_collection=(True))
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %% [markdown]
# (2) Suppose you sample an analog signal $x(t)=1-t$ during the interval $0\leqslant t \leqslant 1 sec$ with a
# sampling period of $0.125$ to generate $x[n]$. Plot $x[n]$, $x[-n]$, $x_{even}[n]$ and $x_{odd}[n]$.

# %%
x(t)=1-t
x(t):

# %%
import numpy as np
import matplotlib.pyplot as plt
t=np.arange(0,1.1,0.1)
x=1-t
plt.plot(t,x)
plt.grid()
plt.title('x(t)', color='b')
plt.xlabel('t'+ r'$\rightarrow$')
plt.ylabel('x(t) '+ r'$\rightarrow$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %%
Sampling period = 0.125s
x[n]:

# %%
t=np.arange(0,1.1,0.125)
x=1-t
plt.stem(t,x)
plt.grid()
plt.title('x[n]', color='b')
plt.xlabel('n'+ r'$\rightarrow$')
plt.ylabel('x[n] '+ r'$\rightarrow$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %%
x[-n]:

# %%
import numpy as np
import matplotlib.pyplot as plt
t=np.arange(-1,0.1,0.125)
x_=1+t
plt.stem(t,x_)
plt.grid()
plt.title('x[-n]', color='b')
plt.xlabel('n'+ r'$\rightarrow$')
plt.ylabel('x[-n] '+ r'$\rightarrow$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %%
x_even[n]:

# %%
import numpy as np
import matplotlib.pyplot as plt
t=np.arange(-1,1.1,0.125)
x_=(1+t)*np.heaviside((-1*t),1)
t1=np.arange(-1,1.1,0.125)
x=(1-t)*np.heaviside(t,1)
x_even=(x+x_)/2
plt.stem(t,x_even)
plt.grid()
plt.title('x_even[n]', color='b')
plt.xlabel('n'+ r'$\rightarrow$')
plt.ylabel('x_even[n] '+ r'$\rightarrow$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %%
x_odd[n]:

# %%
import numpy as np
import matplotlib.pyplot as plt
t=np.arange(-1,1.1,0.125)
x_=(1+t)*np.heaviside((-1*t),1)
t1=np.arange(-1,1.1,0.125)
x=(1-t)*np.heaviside(t,1)
x_odd=(x-x_)/2
plt.stem(t,x_odd)
plt.grid()
plt.title('x_odd[n]', color='b')
plt.xlabel('n'+ r'$\rightarrow$')
plt.ylabel('x_odd[n] '+ r'$\rightarrow$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %% [markdown]
# (3) Let $x[n]=[2, 4, -3, \textbf{1}, -5, 4, 7]$ $-3\leqslant n \leqslant 3$. Generate and plot the samples of the
# following sequences using stem function.
#
# \begin{equation}\nonumber
# (i)~~~~x_{1}[n] = 2x[n-3] + 3x[n + 4] - x[n]
# \end{equation}
# \begin{equation}\nonumber
# (ii)~~~~~~~~~~~x_{2}[n] = x[-n- 4] + x[-n + 4]
# \end{equation}
# \begin{equation}\nonumber
# (iii)~~~~~~~~~~~~~~x_{3}[n] = 2e^{0.5n} x[n] u[-n-1]
# \end{equation}

# %% [markdown]
# (4) Consider the discrete time signal $x[n]=\cos(\frac{2\pi n}{7})$. \
# (i) Obtain and plot the downsampled (decimated) signal $y[n]=x[2n]$ along with $x[n]$\
# (ii) Obtain and plot the upsampled (interpolated) signal $z[n]=x[n/2]$ for $n$ even and $z[n]=0$ otherwise along with $x[n]$

# %% [markdown]
# (5) Generate the following signals with the specified sampling rate and listen to it.
# Let $t$ vary from $0 - 3$seconds.  Let the sampling rate is 8000Hz or a sampling time period is $125 \mu s$
# (A sample is taken at every integer multiple of $125 \mu s$ )
#
# $x(t) = sin(100\pi t)$ (100 Hz sinusoid)\
# $x(t) = cos(1000\pi t)$ (1kHz sinusoid) \
# $x(t) = sin(100 \pi t^2) $  (Called a chirp signal) \
#
# To listen to a signal, write the signal to a file using wave write command  from scipy
# Please look up the documentation here\ (https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.io.wavfile.write.html).   Then download the signal and listen to it.

# %%
x(t)=sin(100*pi*t)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as wav
s_rate=8000
t=np.arange(0,3,1/8000)
sig1=np.sin(2*np.pi*50*t)
wav.write('sig1.wav',s_rate,sig1)

# %%
x(t)=cos(1000*pi*t)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as wav
s_rate=8000
t=np.arange(0,3,1/8000)
sig2=np.cos(2*np.pi*500*t)
wav.write('sig2.wav',s_rate,sig2)

# %%
x(t)=sin(100*pi*t*t)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as wav
s_rate=8000
t=np.arange(0,3,1/8000)
sig3=np.sin(2*np.pi*50*t*t)
wav.write('sig3.wav',s_rate,sig3)

# %% [markdown]
# (6) Sample the signal $cos ( 10 \pi t)$ using the following frequencies (a) 20 Hz (b) 7.5 Hz (c) 5 Hz (d) 2.5 Hz.   In each case, plot the signal and determine its period.

# %%
import numpy as np
import matplotlib.pyplot as plt
t=np.arange(0,1,0.01)
x=np.cos(2*np.pi*5*t)
plt.plot(t,x)
plt.grid()
plt.title('x(t): Cosine Wave', color='b')
plt.xlabel('t'+ r'$\rightarrow$')
plt.ylabel('x(t) '+ r'$\rightarrow$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %%
(a)20 Hz
   x1[n]:

# %%
import numpy as np
import matplotlib.pyplot as plt
n=np.arange(0,1.1,1/20)
x1=np.cos(2*np.pi*5*n)
plt.stem(n,x1)
plt.grid()
plt.title('x1(t): Cosine Wave Fs=20 Hz', color='b')
plt.xlabel('n'+ r'$\rightarrow$')
plt.ylabel('x1(t) '+ r'$\rightarrow$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %%
(b)7.5 Hz
   x2[n]:

# %%
import numpy as np
import matplotlib.pyplot as plt
n=np.arange(0,1.1,1/7.5)
x2=np.cos(2*np.pi*5*n)
plt.stem(n,x2)
plt.grid()
plt.title('x2(t): Cosine Wave Fs=7.5 Hz', color='b')
plt.xlabel('n'+ r'$\rightarrow$')
plt.ylabel('x2(t) '+ r'$\rightarrow$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %%
(c)5 Hz
   x3[n]:

# %%
import numpy as np
import matplotlib.pyplot as plt
n=np.arange(0,1.1,1/5)
x3=np.cos(2*np.pi*5*n)
plt.stem(n,x3)
plt.grid()
plt.title('x3(t): Cosine Wave Fs=5 Hz', color='b')
plt.xlabel('n'+ r'$\rightarrow$')
plt.ylabel('x3(t) '+ r'$\rightarrow$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %%
(d)2.5 Hz
   x4[n]:

# %%
import numpy as np
import matplotlib.pyplot as plt
n=np.arange(0,1.1,1/2.5)
x4=np.cos(2*np.pi*5*n)
plt.stem(n,x4)
plt.grid()
plt.title('x4(t): Cosine Wave Fs=2.5 Hz', color='b')
plt.xlabel('n'+ r'$\rightarrow$')
plt.ylabel('x4(t) '+ r'$\rightarrow$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %% [markdown]
# (7) In DTMF dialling a number is represented by a dual frequency tone. Do a web search and find the frequencies
# of each digit. Generate DTMF tones corresponding to the telephone number $08242474040$ by sampling the sum of sinusoids
# at the required frequencies at $Fs= 8192$ Hz. Concatenate the signals by putting 50 zeros between each signal
# (to represent silence) and listen to the signal. (Must sound like tone dialling the same number from a phone)

# %% [markdown]
# (8) Record your own voice for half a minute and observe the time domain waveform
# (Use any sound recording program, save in $*.wav~~format$ and read it using wavread command in Python for further processing).\
# (i) Find the sampling rate used by the recorder(one of the outputs of wavread)\
# (ii) Compare with the quality of the a standard speech recording (available in moodle)\
# (iii) Find the max/min/average values and energy of the entire signal \
# (iv) Split the signal into segments of $20ms$ long and compute the energy of each segment and plot it. \
# (v) Quantize the above recorded file to (i) Single bit (ii) $4$ Bits (iii) $16$ bits and listen to it.
#      Observe the quantization noise.

# %% [markdown]
# (9) A coarse way to approximate a musical note is to generate a set of harmonics
# (integer multiples of a base frequency) and perform a weighted sum with an amplitude that is slowly
# starting and stopping. Here we try to generate the following approximation to a musical note:
#
# \begin{equation}\nonumber
#  x[n] = \sin(\omega n) + \alpha \sin(2\omega n) + \alpha^2\sin(2\omega n)
# \end{equation}
# \begin{equation}\nonumber
#  w[n] =e^{-\beta_{1}n}(1-e^{-\beta_{2}n})
# \end{equation}
# \begin{equation}\nonumber
#  y[n] =w[n]x[n]
# \end{equation}
#
#
# Start with parameters: $\omega=0.2742830$, $\alpha=0.5$, $\beta_{1}=1e-4$ and $\beta_{2}=1e-3$. Generate $8000$ samples
# $(n = 0......7999)$ of the signal and save the signal as $.wav$ file with sampling frequency $16000$Hz.
# (ie., a note of length $0.5$s)
